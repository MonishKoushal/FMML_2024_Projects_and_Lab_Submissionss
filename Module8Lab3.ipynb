# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-21 13:10:49--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   246MB/s    in 0.3s
#
# 2025-04-21 13:10:50 (246 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26995  1701.07901v1  Instance Search (INS) is a fundamental problem...    cs
# 36809   1412.8704v1  Traditional cognitive science rests on a found...    cs
# 39596  1610.00889v1  The growing popularity of mobile and wearable ...    cs
# 21961   1007.4062v1  Support vector machines (SVMs) are special ker...  stat
# 38455  1802.05853v1  This paper explores the use of multi-view feat...    cs
# ...             ...                                                ...   ...
# 22765  1706.01865v1  Performance of machine learning approaches dep...  stat
# 18128  cs/0405030v1  The rapid e-commerce growth has made both busi...    cs
# 4308    1205.4377v2  In many classification systems, sensing modali...    cs
# 21692   0812.1615v1  Autoencoder neural network is implemented to e...  stat
# 23050  1802.08139v1  We consider the problem of learning fair decis...  stat
#
#                                                    title  year  \
# 26995  Deep Region Hashing for Efficient Large-scale ...  2017
# 36809  Quantum Structure in Cognition and the Foundat...  2014
# 39596  Cardea: Context-Aware Visual Privacy Protectio...  2016
# 21961  Support Vector Machines for Additive Models: C...  2010
# 38455  Articulatory information and Multiview Feature...  2018
# ...                                                  ...   ...
# 22765                         Shape Parameter Estimation  2017
# 18128        Business Intelligence from Web Usage Mining  2004
# 4308                       Multi-Stage Classifier Design  2012
# 21692  Missing Data using Decision Forest and Computa...  2008
# 23050              Path-Specific Counterfactual Fairness  2018
#
#                                                 keywords
# 26995  [fundamental, applications, challenging, compa...
# 36809  [traditional, cognitive, foundation, classical...
# 39596  [popularity, applications, augmented, increase...
# 21961  [successful, informally, described, regularize...
# 38455  [discriminative, transforms, convolutional, ar...
# ...                                                  ...
# 22765  [performance, approaches, parameters, threshol...
# 18128  [community, customers, situation, competition,...
# 4308   [classification, modalities, different, acquis...
# 21692  [autoencoder, implemented, algorithm, implemen...
# 23050  [scenarios, sensitive, attribute, introduce, d...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26995    [fundamental, applications, challenging, compa...
# 36809    [traditional, cognitive, foundation, classical...
# 39596    [popularity, applications, augmented, increase...
# 21961    [successful, informally, described, regularize...
# 38455    [discriminative, transforms, convolutional, ar...
#                                ...
# 7689     [permutations, matchings, canonicalize, diffic...
# 23875    [operators, guillemotleft, guillemotright, par...
# 6182     [artificial, propagation, algorithm, propagati...
# 31051    [morphological, diagnosis, melanocytic, multir...
# 39793    [localization, environments, fundamental, capa...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8808 words.
# Out of those 4475 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5a51ab81-6def-45eb-8504-b3f0d7e96da0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a51ab81-6def-45eb-8504-b3f0d7e96da0")) {                    Plotly.newPlot(                        "5a51ab81-6def-45eb-8504-b3f0d7e96da0",                        [{"x":["extraction","extracting","bottleneck","application","applications","specifically","performance","effective","generated","fundamental","challenging","demonstrated","relevancy","convolutional","effectiveness","dimensional","comparing","efficient","traditional","typically","proposals","conducted","separated","experimental","generation","collapses","handcrafted","efficiency","generating","cognition","interpreted","situations","foundation","deviations","seriously","classical","formalism","successful","perspective","explanatory","formulate","superposition","emergence","expressions","classically","reasoning","combinations","theoretic","algebraic","psychology","meanwhile","conceptual","foundations","structure","cognitive","challenged","processes","probability","hypothesis","framework","evaluation","interactive","dependent","protection","automatically","augmented","techniques","practical","increased","preferences","individuals","according","inevitably","indicators","promising","motivated","implement","pervasive","facilitated","popularity","consisting","estimators","classification","qualitative","corresponding","prediction","robustness","knowledge","universally","estimated","consistent","insensitive","combination","interpretability","functions","usefulness","informally","statistical","continuous","consistency","complicated","statistically","construction","semiparametric","nonparametric","regularized","regression","concentrated","distribution","lipschitz","reproducing","described","telephone","perceptually","transforms","vocabulary","reduction","demonstrate","oscillator","themselves","multiview","conversational","representation","association","coefficient","individual","spontaneous","discriminative","articulatory","filterbank","significant","recognition","likelihood","architecture","information","additional","therefore","unbalanced","substantial","algorithms","furthermore","generalized","coordinate","penalties","optimization","regularization","screening","experiments","procedures","penalized","algorithm","numerical","estimation","parameters","advantages","simulated","discrimination","performed","important","expressiveness","comparison","identification","suggesting","sensitivity","inequalities","distributions","criterion","segmentation","outperforms","distances","statistics","variation","literature","polarimetric","particular","asymptotic","statistic","capabilities","illustrate","homogeneity","stochastic","dissimilarity","aggregating","occurrence","incapable","documents","associations","occurrences","interesting","interactions","assumption","incorporates","identifying","straightforward","personalized","represented","structured","classifier","extracted","postulating"],"y":[131,54,16,266,448,175,909,254,161,98,239,102,2,378,202,205,71,429,163,100,31,70,12,394,135,3,8,147,107,9,17,43,11,12,3,100,20,79,65,2,57,3,17,36,2,135,47,40,9,8,17,17,12,324,39,4,108,163,65,560,249,36,80,5,183,42,416,145,44,33,42,102,5,10,126,70,75,4,2,21,54,15,511,68,119,221,95,338,3,53,55,1,117,20,207,37,0,153,101,49,38,19,67,1,21,32,114,3,227,8,8,77,4,7,19,33,113,538,2,23,9,10,361,33,27,115,6,93,2,3,219,383,73,269,657,120,151,3,44,624,168,58,27,2,321,91,9,616,42,10,793,80,192,257,75,61,12,134,348,7,130,112,11,39,2,134,55,206,258,35,56,58,131,1,270,10,10,40,84,2,131,7,11,23,2,64,8,15,67,88,55,37,69,24,8,74,97,139,113,2],"type":"bar"},{"x":["extraction","extracting","bottleneck","application","applications","s ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4475,), (4475, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.795

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Self</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Contained</span> <span style=''>and</span> <span style=''>Easily</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Accessible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discussion</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Method</span> <span style=''>of</span> <span style=''>Descente</span> <span style=''>Infinie</span> <span style=''>and</span> <span style=''>Fermats</span> <span style=''>Only</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Explicitly</span> <span style=''>Known</span> <span style=''>Proof</span> <span style=''>by</span> <span style=''>Descente</span> <span style=''>Infinie</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>the</span> <span style=''>only</span> <span style=''>proof</span> <span style=''>of</span> <span style=''>Pierre</span> <span style=''>Fermat</span> <span style=''>by</span> <span style=''>descente</span> <span style=''>infinie</span> <span style=''>that</span> <span style=''>is</span> <span style=''>known</span> <span style=''>to</span> <span style=''>exist</span> <span style=''>today</span> <span style=''>As</span> <span style=''>the</span> <span style=''>text</span> <span style=''>of</span> <span style=''>its</span> <span style=''>Latin</span> <span style=''>original</span> <span style=''>requires</span> <span style=''>active</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mathematical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>it</span> <span style=''>is</span> <span style=''>more</span> <span style=''>a</span> <span style=''>proof</span> <span style=''>sketch</span> <span style=''>than</span> <span style=''>a</span> <span style=''>proper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mathematical</span> <span style=''>proof</span> <span style=''>We</span> <span style=''>discuss</span> <span style=''>descente</span> <span style=''>infinie</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mathematical</span> <span style=''>logical</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>historical</span> <span style='background-color:rgba(0, 255, 0, 0.8840579710144927);'>linguistic</span> <span style=''>and</span> <span style=''>refined</span> <span style=''>logic</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>historical</span> <span style=''>points</span> <span style=''>of</span> <span style=''>view</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>the</span> <span style=''>required</span> <span style=''>preliminaries</span> <span style=''>from</span> <span style=''>number</span> <span style=''>theory</span> <span style=''>and</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>self</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contained</span> <span style=''>proof</span> <span style=''>in</span> <span style=''>a</span> <span style=''>modern</span> <span style=''>form</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nevertheless</span> <span style=''>is</span> <span style=''>intended</span> <span style=''>to</span> <span style=''>follow</span> <span style=''>Fermats</span> <span style=''>ideas</span> <span style=''>closely</span> <span style=''>We</span> <span style=''>then</span> <span style=''>annotate</span> <span style=''>an</span> <span style=''>English</span> <span style='background-color:rgba(0, 255, 0, 0.8103448275862069);'>translation</span> <span style=''>of</span> <span style=''>Fermats</span> <span style=''>original</span> <span style=''>proof</span> <span style=''>with</span> <span style=''>terms</span> <span style=''>from</span> <span style=''>the</span> <span style=''>modern</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Interesting</span> <span style=''>data</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>concentrate</span> <span style=''>on</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>smooth</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>inside</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>ambient</span> <span style=''>space</span> <span style=''>Random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>are</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>powerful</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>of</span> <span style=''>such</span> <span style=''>data</span> <span style=''>Previous</span> <span style=''>works</span> <span style=''>have</span> <span style=''>studied</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>how</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>are</span> <span style=''>needed</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accurately</span> <span style=''>preserve</span> <span style=''>the</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>given</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>volume</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>curvature</span> <span style=''>However</span> <span style=''>such</span> <span style=''>works</span> <span style=''>employ</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definitions</span> <span style=''>of</span> <span style=''>volume</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>curvature</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inherently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>such</span> <span style=''>theory</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>tested</span> <span style=''>against</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tightness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proven</span> <span style=''>bounds</span> <span style=''>We</span> <span style=''>instead</span> <span style=''>study</span> <span style=''>typical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distortions</span> <span style=''>arising</span> <span style=''>in</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>of</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.6000000000000001);'>Kronecker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Determinantal</span> <span style=''>Point</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Determinantal</span> <span style=''>Point</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <span style=''>(DPPs)</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>over</span> <span style=''>all</span> <span style=''>subsets</span> <span style=''>a</span> <span style=''>ground</span> <span style=''>set</span> <span style=''>of</span> <span style=''>N</span> <span style=''>items</span> <span style=''>They</span> <span style=''>have</span> <span style=''>recently</span> <span style=''>gained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prominence</span> <span style=''>in</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>that</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>diverse</span> <span style=''>subsets</span> <span style=''>However</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicability</span> <span style=''>to</span> <span style=''>large</span> <span style=''>problems</span> <span style=''>is</span> <span style=''>still</span> <span style=''>limited</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>mathcal</span> <span style=''>O(N3)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>core</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style=''>sampling</span> <span style=''>and</span> <span style=''>learning</span> <span style=''>We</span> <span style=''>enable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>sampling</span> <span style=''>and</span> <span style=''>learning</span> <span style=''>for</span> <span style=''>DPPs</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introducing</span> <span style=''>KronDPP</span> <span style=''>a</span> <span style=''>DPP</span> <span style=''>model</span> <span style=''>whose</span> <span style=''>kernel</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>decomposes</span> <span style=''>as</span> <span style=''>a</span> <span style=''>tensor</span> <span style=''>product</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>smaller</span> <span style=''>kernel</span> <span style=''>matrices</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>immediately</span> <span style=''>enables</span> <span style=''>fast</span> <span style=''>exact</span> <span style=''>sampling</span> <span style=''>But</span> <span style=''>contrary</span> <span style=''>to</span> <span style=''>what</span> <span style=''>one</span> <span style=''>may</span> <span style=''>expect</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6000000000000001);'>Kronecker</span> <span style=''>product</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>for</span> <span style=''>speeding</span> <span style=''>up</span> <span style=''>DPP</span> <span style=''>learning</span> <span style=''>turns</span> <span style=''>out</span> <span style=''>to</span> <span style=''>be</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffic ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Dental</span> <span style=''>Image</span> <span style=''>Analysis</span> <br/><br/><span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artificial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intelligence</span> <span style=''>(AI)</span> <span style=''>to</span> <span style=''>dental</span> <span style=''>imaging</span> <span style=''>we</span> <span style=''>applied</span> <span style=''>AI</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technology</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>panoramic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>radiographs</span> <span style=''>using</span> <span style=''>(a)</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>(CNN)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>form</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artificial</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>(ANN)</span> <span style=''>(b)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representative</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cognition</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>(SIFT)</span> <span style=''>and</span> <span style=''>(c)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>histogram</span> <span style=''>of</span> <span style=''>oriented</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>(HOG)</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10439756882373973)
# 	representation (0.12906685734715767)
# 	knowledge (0.12084376117268501)
# 	segmentation (0.0736503396496246)
# 	experimental (0.14086521272792277)
# 	architecture (0.09617447264926707)
# 	detection (0.12191633893457275)
# 	different (0.27064712191633894)
# 	convolutional (0.13514479799785484)
# 	recognition (0.13693242760100108)
#
# Some Statistics words are:
# 	stochastic (0.13130304543185223)
# 	theoretical (0.14877683474787817)
# 	statistical (0.1492760858711932)
# 	distribution (0.1797304043934099)
# 	variables (0.14278582126809786)
# 	estimation (0.17124313529705443)
# 	algorithm (0.39540688966550175)
# 	dimensional (0.1872191712431353)
# 	inference (0.1967049425861208)
# 	regression (0.18272591113330006)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ef832e43-de7a-4592-806f-3f7a9145c658" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef832e43-de7a-4592-806f-3f7a9145c658")) {                    Plotly.newPlot(                        "ef832e43-de7a-4592-806f-3f7a9145c658",                        [{"x":["extraction","extracting","bottleneck","application","applications","specifically","performance","effective","generated","fundamental","challenging","demonstrated","relevancy","convolutional","effectiveness","dimensional","comparing","efficient","traditional","typically","proposals","conducted","separated","experimental","generation","collapses","handcrafted","efficiency","generating","cognition","interpreted","situations","foundation","deviations","seriously","classical","formalism","successful","perspective","explanatory","formulate","superposition","emergence","expressions","classically","reasoning","combinations","theoretic","algebraic","psychology","meanwhile","conceptual","foundations","structure","cognitive","challenged","processes","probability","hypothesis","framework","evaluation","interactive","dependent","protection","automatically","augmented","techniques","practical","increased","preferences","individuals","according","inevitably","indicators","promising","motivated","implement","pervasive","facilitated","popularity","consisting","estimators","classification","qualitative","corresponding","prediction","robustness","knowledge","universally","estimated","consistent","insensitive","combination","interpretability","functions","usefulness","informally","statistical","continuous","consistency","complicated","statistically","construction","semiparametric","nonparametric","regularized","regression","concentrated","distribution","lipschitz","reproducing","described","telephone","perceptually","transforms","vocabulary","reduction","demonstrate","oscillator","themselves","multiview","conversational","representation","association","coefficient","individual","spontaneous","discriminative","articulatory","filterbank","significant","recognition","likelihood","architecture","information","additional","therefore","unbalanced","substantial","algorithms","furthermore","generalized","coordinate","penalties","optimization","regularization","screening","experiments","procedures","penalized","algorithm","numerical","estimation","parameters","advantages","simulated","discrimination","performed","important","expressiveness","comparison","identification","suggesting","sensitivity","inequalities","distributions","criterion","segmentation","outperforms","distances","statistics","variation","literature","polarimetric","particular","asymptotic","statistic","capabilities","illustrate","homogeneity","stochastic","dissimilarity","aggregating","occurrence","incapable","documents","associations","occurrences","interesting","interactions","assumption","incorporates","identifying","straightforward","personalized","represented","structured","classifier","extracted","postulating","databases","complement","predicting","different","transferring","contemporary","difficulty","translators","sentences","alignment","constructs","unsupervised","circumstances","background","automatic","development","orderings","integrate","variables","programming","constraint","theoretical","lexicographic","potentially","comparisons","significantly","representations","cardinality","successfully","propagation","empirical","compactness","interfaces","unfortunately","extensibility","maintainability","multimodal","functional","introduce","expansion","standardized","component","developing","elaborate","comprehensive","analyzing","challenge","dimensions","artificial","scientists","construct","extractors","expressed","pipeli ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	informally
# 	cybersecurity
# 	inspecting
# 	collapsing
# 	debiasing
# 	privately
# 	nonparametrically
# 	confounders
# 	trilinear
# 	lindenstrauss
# 	incoherence
# 	entrywise
# 	specialize
# 	movielens
# 	tibshirani
# 	smoothers
# 	parallelisation
# 	diagonalise
# 	persistence
# 	simulators
# Some words which never appear in Statistics papers:
# 	collapses
# 	seriously
# 	classically
# 	telephone
# 	perceptually
# 	oscillator
# 	conversational
# 	spontaneous
# 	articulatory
# 	filterbank
# 	postulating
# 	translators
# 	orderings
# 	lexicographic
# 	maintainability
# 	extractors
# 	troublesome
# 	taxonomies
# 	betterment
# 	spatialtemporal

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.082139004469102e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7491666666666666
