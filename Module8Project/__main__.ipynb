# %%
import numpy as np

from autohire.utils import parse_pdf, parse_resume_df
from autohire.bow import BagOfWords
from autohire.encoder import LabelEncoder
from autohire.model import BayesianMulticlassModel
from autohire.explainer import BayesianModelExplainer


if __name__ == "__main__":
    x_train, y_train = parse_resume_df()
    bag_of_words = BagOfWords(x_train)
    label_encoder = LabelEncoder(y_train)

    x_train = bag_of_words.get_counts(x_train)
    y_train = label_encoder.encode(y_train)
    model = BayesianMulticlassModel(len(label_encoder), len(bag_of_words))
    model.fit(x_train=x_train, y_train=y_train)

    x_test_input = parse_pdf("data/resumes/computers_2.pdf")
    x_test = bag_of_words.get_counts(x_test_input)
    result = model.predict(x_train[0])
    result = label_encoder.decode(result)

    for job in result[:5]:
        print(job)

    explainable_model = BayesianModelExplainer(label_encoder, bag_of_words)
    explainable_model.fit(x_train=x_train, y_train=y_train)

    print(
        """
ANALYSIS OF TRAINED PRIOR
-------------------------"""
    )
    explainable_model.explain()

    print(
        """
ANALYSIS OF TRAINED EVIDENCE
----------------------------"""
    )
    explainable_model.explain(x_test_input)
# Out:
# Data Science
# Civil Engineer
# Mechanical Engineer
# Operations Manager
# Health and fitness
#
# ANALYSIS OF TRAINED PRIOR
# -------------------------
# Operations Manager: ges korea shipments hpm qatar monitored prepaid marshalling honeywell fat
# DevOps Engineer: workload allocate eclerx biztalk birla wwf solid ada annet knoxed
# PMO: dollars ratios pivots impacting collate saints particularly transitioned paced konkani
# Hadoop: affect zookeeper hat hdp vaccines uses heights hiveql handy hpe
# ETL Developer: mart niche advertisement aggregator agnel athena rejection tftput prabhakar tftpconnection
# Business Analyst: proteus installations concerned zambia bau configurations hiral observation infonet plastics
# Java Developer: resrent pjlce newspapers validations deduplication december debug debtor sierra ordering
# Web Designing: golchha nettech movie nitka diifernt iv diagnosis cityspaceindia shooping incorporate
# Data Science: yyyy addresses xii adjunct ymcaust advocator aeronautics accelerating accelerator vader
# Testing: powai tapping madhyamik vidyalaya sinhagad wagheducation pravaranagar silverline changer suncity
# Database: rcu vulnerability pci tdp periodically packard vsphere tns deleting reorganize
# Mechanical Engineer: bangladesh pneumatics joist thumb jsw rajdevi race throttle thane rabale
# Automation Testing: phython inert underwent rich induction independent bottle rheinland druck unity
# Network Security Engineer: nexus zenoss qms wds proliant bmc sinhgad thrive reconnaissance url
# SAP Developer: qm sinochem aero adaptable lenm solved lean pictures varies landscape
# Blockchain: adhar jharnet jspm ka manageable shree reactjs scholar specilaized vidyashram
# Python Developer: pict navigation liabray jscoe liabrary printer proficiencies managent switched accountabilities
# DotNet Developer: tourist contactus gallery calendar cb stadio dress cheques sms cmus
# Arts: definitive kubler rachana sci mixing longer atd youth solutionseducation exclusive
# Electrical Engineering: matched cadd switchgears analog amreli amf allied electromech submersible allen
# Civil Engineer: toyo inspect indiaeducation lodha cohesion valid colony outfit compiling complies
# Sales: ranked mahal caller tournaments tournament emperor convincing bookmyflat cooperatively preferred
# Health and fitness: medicals rotas florida reps contribute garware vlcc practicing conveying supplements
# HR: nani welfare esic staffs mgt deduction thrissur psychotherapy establishments facilitation
# Advocate: succession liaisoning madras literature researcher bci nibs extraeducation walks sole
#
# ANALYSIS OF TRAINED EVIDENCE
# ----------------------------
# Operations Manager: and in for ja with of le india ma assistant
# DevOps Engineer: ai tion buy ear amazon sensor labs watch hyderabad swing
# PMO: linguistic tagging statistical delhi inter ad metrics optimization pan certification
# Hadoop: de schedulers red commands distributed applied star watch vice shopping
# ETL Developer: award together cbse applied star error long organized written here
# Business Analyst: ios sciences community passing book computers block object methods search
# Java Developer: december facebook swing subjects computers courses stack object methods oriented
# Web Designing: videos mini op shopping search ideas competition app modern structure
# Data Science: teaching tf linkedin notebooks animeshsinha segmentation google ai participants subjects
# Testing: singh mini competitive rd op cyber list current certification assembly
# Database: sync amazon gr schedulers ma statistics applied commands statistical watch
# Mechanical Engineer: coordinator contest piping supervision round rd among competition structure chain
# Automation Testing: enable bulk piping sensor star indian ap black object oct
# Network Security Engineer: sa ios stack ap filtering ideas inter content routing pan
# SAP Developer: passing round object ideas show inter oriented certification app member
# Blockchain: chess une endpoints intern react cbse block stack shopping food
# Python Developer: rank competitions round organized github filtering inter coding methods oriented
# DotNet Developer: community man book courses shopping associated list coding show content
# Arts: camp passing award art together indian total term organized delhi
# Electrical Engineering: sat prof ac statistics book courses indian associated hyderabad coding
# Civil Engineer: near om piping supervision man natural round indian al list
# Sales: visualizing sciences computers entry show written here assistant best set
# Health and fitness: participants community statistical club food organized written certification app st
# HR: error hyderabad inter here assistant course master july processing school
# Advocate: researcher sole singh supervision natural indian search hyderabad member july
